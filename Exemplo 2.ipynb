# %%
import pandas as pd

# %%
#index_col = defne quais colunas ser]ao usadas como indice do df, por default ele cria uma nova coluna
#index_col = pode utilizar o nome da coluna ou o index da coluna
reviews = pd.read_csv('Contoso - Vendas  - 2017.csv', sep=';', index_col=0)
display(reviews)
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 1                  01/01/2017    02/01/2017         1       86         981
# 2                  01/01/2017    06/01/2017         5      308        1586
# 3                  01/01/2017    01/01/2017         0      294        1444
# 4                  01/01/2017    01/01/2017         0      251        1468
# 5                  01/01/2017    07/01/2017         6       94        1106
# ...                       ...           ...       ...      ...         ...
# 980638             31/12/2017    31/12/2017         0      194        2490
# 980639             31/12/2017    06/01/2018         6       32        2488
# 980640             31/12/2017    03/01/2018         3      210        2511
# 980641             31/12/2017    31/12/2017         0       53         436
# 980642             31/12/2017    31/12/2017         0      309        2510
#
# ...

# %%
#adicionando + 10 na quantidade vendida
reviews_df = reviews[['Quantidade Vendida']].apply(lambda x : x + 10)

# %%
display(reviews_df)
display(reviews)
# Out:
#                  Quantidade Vendida
# Numero da Venda
# 1                                19
# 2                                19
# 3                                23
# 4                                16
# 5                                14
# ...                             ...
# 980638                          130
# 980639                          130
# 980640                           90
# 980641                           49
# 980642                           90
#
# [980642 rows x 1 columns]
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 1                  01/01/2017    02/01/2017         1       86         981
# 2                  01/01/2017    06/01/2017         5      308        1586
# 3                  01/01/2017    01/01/2017         0      294        1444
# 4                  01/01/2017    01/01/2017         0      251        1468
# 5                  01/01/2017    07/01/2017         6       94        1106
# ...

# %%
# acessando a propriedades da coluna
reviews['ID Loja']
# Out:
# Numero da Venda
# 1          86
# 2         308
# 3         294
# 4         251
# 5          94
#          ...
# 980638    194
# 980639     32
# 980640    210
# 980641     53
# 980642    309
# Name: ID Loja, Length: 980642, dtype: int64

# %%
reviews['ID Loja'][3]
# Out:
# 294

# %%
# pega a primeira linha de um df
reviews.iloc[0]
# Out:
# Data da Venda           01/01/2017
# Data do Envio           02/01/2017
# ID Canal                         1
# ID Loja                         86
# ID Produto                     981
# ID Promocao                      2
# ID Cliente                    6825
# Quantidade Vendida               9
# Quantidade Devolvida             1
# Name: 1, dtype: object

# %%
# linhas da primeira coluna (id cliente)
reviews.iloc[:, 6]
# Out:
# Numero da Venda
# 1          6825
# 2         18469
# 3         19730
# 4         29326
# 5         22617
#           ...
# 980638    10353
# 980639    31750
# 980640    12003
# 980641    25550
# 980642    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
# as 3 primeiras linhas da coluna id cliente
reviews.iloc[:3,6]
# Out:
# Numero da Venda
# 1     6825
# 2    18469
# 3    19730
# Name: ID Cliente, dtype: int64

# %%
# pegando a segunda e terceira linha da coluna
reviews.iloc[1:3,6]
# Out:
# Numero da Venda
# 2    18469
# 3    19730
# Name: ID Cliente, dtype: int64

# %%
reviews.iloc[[0,1,2,3], 6]
# Out:
# Numero da Venda
# 1     6825
# 2    18469
# 3    19730
# 4    29326
# Name: ID Cliente, dtype: int64

# %%
# pegando os 5 ultimos da coluna cliente
reviews.iloc[-5:, 6]
# Out:
# Numero da Venda
# 980638    10353
# 980639    31750
# 980640    12003
# 980641    25550
# 980642    28707
# Name: ID Cliente, dtype: int64

# %%
#loc considera o valor do indice, não o index no caso do iloc
reviews.loc[1,'ID Cliente']
# Out:
# 6825

# %%
reviews.loc[:,['ID Loja', 'ID Cliente']]
# Out:
#                  ID Loja  ID Cliente
# Numero da Venda
# 1                     86        6825
# 2                    308       18469
# 3                    294       19730
# 4                    251       29326
# 5                     94       22617
# ...                  ...         ...
# 980638               194       10353
# 980639                32       31750
# 980640               210       12003
# 980641                53       25550
# 980642               309       28707
#
# [980642 rows x 2 columns]

# %%
reviews['ID Cliente'] == 19730
# Out:
# Numero da Venda
# 1         False
# 2         False
# 3          True
# 4         False
# 5         False
#           ...
# 980638    False
# 980639    False
# 980640    False
# 980641    False
# 980642    False
# Name: ID Cliente, Length: 980642, dtype: bool

# %%
# todas as vendas do cliente 19730
reviews.loc[reviews['ID Cliente'] == 19730]
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 3                  01/01/2017    01/01/2017         0      294        1444
# 44804              19/01/2017    19/01/2017         0      221        1330
# 69477              30/01/2017    06/02/2017         7      172        1090
# 85186              05/02/2017    14/02/2017         9      306        1352
# 116837             18/02/2017    22/02/2017         4      131        1632
# 173131             13/03/2017    13/03/2017         0       73        1659
# 258271             14/04/2017    15/04/2017         1      200         687
# 340561             11/05/2017    20/05/2017         9      188         243
# 427691             08/06/2017    11/06/2017         3      186        1141
# 432445             10/06/2017    10/06/2017         0      181        1405
# 433214             10/06/2017    19/06/2017         9       89         708
# ...

# %%
# vendas dos funcionários 19730 com a quantidade vendida maior que 10
reviews.loc[(reviews['ID Cliente'] == 19730) & (reviews['Quantidade Vendida'] > 10)]
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 3                  01/01/2017    01/01/2017         0      294        1444
# 85186              05/02/2017    14/02/2017         9      306        1352
# 556370             25/07/2017    25/07/2017         0      172         731
# 584561             06/08/2017    06/08/2017         0       13        1528
# 849449             12/11/2017    15/11/2017         3      132        1650
# 856065             14/11/2017    14/11/2017         0       32         282
# 965255             26/12/2017    26/12/2017         0       63        1219
#
#                  ID Promocao  ID Cliente  Quantidade Vendida  \
# Numero da Venda
# 3                          5       19730                  13
# 85186                      8       19730                  24
# 556370                     3       19730                  12
# 584561                     3       19730                  12
# ...

# %%
# com OU
reviews.loc[(reviews['ID Cliente'] == 19730) | (reviews['Quantidade Vendida'] > 10)]
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 3                  01/01/2017    01/01/2017         0      294        1444
# 16                 01/01/2017    06/01/2017         5      309         599
# 24                 01/01/2017    02/01/2017         1      200         701
# 25                 01/01/2017    02/01/2017         1      309        2517
# 26                 01/01/2017    05/01/2017         4      199         348
# ...                       ...           ...       ...      ...         ...
# 980638             31/12/2017    31/12/2017         0      194        2490
# 980639             31/12/2017    06/01/2018         6       32        2488
# 980640             31/12/2017    03/01/2018         3      210        2511
# 980641             31/12/2017    31/12/2017         0       53         436
# 980642             31/12/2017    31/12/2017         0      309        2510
#
# ...

# %%
# isin permite selecionar dados cujo valor "está dentro" de uma lista
# pegando apenas esses dois clientes
reviews.loc[reviews['ID Cliente'].isin([19730, 27645])]
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 3                  01/01/2017    01/01/2017         0      294        1444
# 16                 01/01/2017    06/01/2017         5      309         599
# 8398               04/01/2017    04/01/2017         0      200        1059
# 18933              08/01/2017    08/01/2017         0      204         642
# 21797              10/01/2017    13/01/2017         3       27         727
# ...                       ...           ...       ...      ...         ...
# 913631             06/12/2017    08/12/2017         2      200         400
# 963681             25/12/2017    26/12/2017         1      306         426
# 965255             26/12/2017    26/12/2017         0       63        1219
# 971804             28/12/2017    28/12/2017         0      218         300
# 973890             29/12/2017    29/12/2017         0      309        1376
#
# ...

# %%
# passando por lista
lista = [19730, 27645]
reviews.loc[reviews['ID Cliente'].isin(lista)]
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 3                  01/01/2017    01/01/2017         0      294        1444
# 16                 01/01/2017    06/01/2017         5      309         599
# 8398               04/01/2017    04/01/2017         0      200        1059
# 18933              08/01/2017    08/01/2017         0      204         642
# 21797              10/01/2017    13/01/2017         3       27         727
# ...                       ...           ...       ...      ...         ...
# 913631             06/12/2017    08/12/2017         2      200         400
# 963681             25/12/2017    26/12/2017         1      306         426
# 965255             26/12/2017    26/12/2017         0       63        1219
# 971804             28/12/2017    28/12/2017         0      218         300
# 973890             29/12/2017    29/12/2017         0      309        1376
#
# ...

# %%
reviews.loc[reviews['Quantidade Vendida'].notnull()]
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 1                  01/01/2017    02/01/2017         1       86         981
# 2                  01/01/2017    06/01/2017         5      308        1586
# 3                  01/01/2017    01/01/2017         0      294        1444
# 4                  01/01/2017    01/01/2017         0      251        1468
# 5                  01/01/2017    07/01/2017         6       94        1106
# ...                       ...           ...       ...      ...         ...
# 980638             31/12/2017    31/12/2017         0      194        2490
# 980639             31/12/2017    06/01/2018         6       32        2488
# 980640             31/12/2017    03/01/2018         3      210        2511
# 980641             31/12/2017    31/12/2017         0       53         436
# 980642             31/12/2017    31/12/2017         0      309        2510
#
# ...

# %%
# adicionando uma coluna (quando não encontra ele cria)
reviews['Topezeira'] = 'testando'
reviews
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 1                  01/01/2017    02/01/2017         1       86         981
# 2                  01/01/2017    06/01/2017         5      308        1586
# 3                  01/01/2017    01/01/2017         0      294        1444
# 4                  01/01/2017    01/01/2017         0      251        1468
# 5                  01/01/2017    07/01/2017         6       94        1106
# ...                       ...           ...       ...      ...         ...
# 980638             31/12/2017    31/12/2017         0      194        2490
# 980639             31/12/2017    06/01/2018         6       32        2488
# 980640             31/12/2017    03/01/2018         3      210        2511
# 980641             31/12/2017    31/12/2017         0       53         436
# 980642             31/12/2017    31/12/2017         0      309        2510
#
# ...

# %%
# criando uma coluna com ao contrario
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews
# Out:
#                 Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# Numero da Venda
# 1                  01/01/2017    02/01/2017         1       86         981
# 2                  01/01/2017    06/01/2017         5      308        1586
# 3                  01/01/2017    01/01/2017         0      294        1444
# 4                  01/01/2017    01/01/2017         0      251        1468
# 5                  01/01/2017    07/01/2017         6       94        1106
# ...                       ...           ...       ...      ...         ...
# 980638             31/12/2017    31/12/2017         0      194        2490
# 980639             31/12/2017    06/01/2018         6       32        2488
# 980640             31/12/2017    03/01/2018         3      210        2511
# 980641             31/12/2017    31/12/2017         0       53         436
# 980642             31/12/2017    31/12/2017         0      309        2510
#
# ...
